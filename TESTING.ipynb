# %% [markdown]
# # WHATEVER YOU DO DONT RUN THE WHOLE NOTEBOOK !!!! API CALLS WILL BE GONE

# %% [markdown]
# The parts that chew up the API calls are near the very bottom, and labeled via comments. Feel free to run the notebook and check out the DataViz, Tables are NOT generated in this
# notebook, instead use the exploratory_analysis notebook to export DF's to the folder the notebooks are in.

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import psycopg2
import datetime as dt
import requests
from collections import Counter
import pickle

import os
API_key = os.environ.get('WWO_API_key')

# %%
##### LOAD IN FROM HERE TO SAVE TIME (FILES CREATED IN EDA notebook)

df = pd.read_csv('flights1500.csv')


file_handler1 = open('flights_months.obj', 'rb')
months = pickle.load(file_handler1)

file_handler2 = open('flights_wmonths.obj', 'rb')
wmonths = pickle.load(file_handler2)

df2 = pd.read_csv('df2.csv')

file_handler3 = open('flights_fuel_months.obj', 'rb')
fuel_months_df = pickle.load(file_handler3)

# %%
df.dtypes
# Out:
# fl_date                 object
# mkt_unique_carrier      object
# branded_code_share      object
# mkt_carrier             object
# mkt_carrier_fl_num       int64
# op_unique_carrier       object
# tail_num                object
# op_carrier_fl_num        int64
# origin_airport_id        int64
# origin                  object
# origin_city_name        object
# dest_airport_id          int64
# dest                    object
# dest_city_name          object
# crs_dep_time             int64
# dep_time               float64
# dep_delay              float64
# taxi_out               float64
# wheels_off             float64
# wheels_on              float64
# taxi_in                float64
# crs_arr_time             int64
# arr_time               float64
# arr_delay              float64
# cancelled              float64
# cancellation_code      float64
# diverted               float64
# dup                     object
# crs_elapsed_time       float64
# actual_elapsed_time    float64
# air_time               float64
# flights                float64
# distance               float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# first_dep_time         float64
# total_add_gtime        float64
# longest_add_gtime      float64
# no_name                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fl_date                   0
# mkt_unique_carrier        0
# branded_code_share        0
# mkt_carrier               0
# mkt_carrier_fl_num        0
# op_unique_carrier         0
# tail_num                  0
# op_carrier_fl_num         0
# origin_airport_id         0
# origin                    0
# origin_city_name          0
# dest_airport_id           0
# dest                      0
# dest_city_name            0
# crs_dep_time              0
# dep_time                  0
# dep_delay                 0
# taxi_out                  1
# wheels_off                1
# wheels_on                 1
# taxi_in                   1
# crs_arr_time              0
# arr_time                  0
# arr_delay                 0
# cancelled                 0
# cancellation_code      1469
# diverted                  0
# dup                       0
# crs_elapsed_time          0
# actual_elapsed_time       0
# air_time                  1
# flights                   0
# distance                  0
# carrier_delay          1182
# weather_delay          1182
# nas_delay              1182
# security_delay         1182
# late_aircraft_delay    1182
# first_dep_time         1463
# total_add_gtime        1463
# longest_add_gtime      1463
# no_name                1469
# dtype: int64

# %%
df.columns
# Out:
# Index(['fl_date', 'mkt_unique_carrier', 'branded_code_share', 'mkt_carrier',
#        'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'dup', 'crs_elapsed_time',
#        'actual_elapsed_time', 'air_time', 'flights', 'distance',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay', 'first_dep_time', 'total_add_gtime',
#        'longest_add_gtime', 'no_name'],
#       dtype='object')

# %%
x = df['distance']
y = df['arr_delay']

# %%
plt.scatter(x,y)
plt.xlabel('Flight distance in miles')
plt.ylabel('Arrival delay (minutes)')
# Out:
# Text(0, 0.5, 'Arrival delay (minutes)')

# %%
df['mkt_carrier'].unique()
# Out:
# array(['DL', 'AA', 'AS', 'WN', 'UA', 'NK', 'G4', 'F9', 'B6', 'HA', 'VX'],
#       dtype=object)

# %%
sns.boxplot(x='mkt_carrier', y="arr_delay", data=df)
# Out:
# <AxesSubplot:xlabel='mkt_carrier', ylabel='arr_delay'>

# %%
a4_dims = (28, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.boxplot(x='dest', y="arr_delay", data=df, ax=ax)
plt.xticks(rotation=90)
plt.show()

# %%
df[['dep_time','crs_dep_time']]
# Out:
#       dep_time  crs_dep_time
# 0       1054.0          1105
# 1       1240.0          1245
# 2       1513.0          1516
# 3        520.0           520
# 4       1838.0          1850
# ...        ...           ...
# 1464    1652.0          1700
# 1465    1551.0          1545
# 1466     944.0           956
# 1467    1148.0          1155
# 1468    1119.0          1125
#
# [1469 rows x 2 columns]

# %%
# mkt_carrier
# origin
# dest
# dest_city_name
# distance
# flights
# carrier_delay
# weather_delay
# air_time
# fl_date

# %%
# Finds correct index for WWO json for the right 3 hour period, in order to find weather description

# parameters(time (h,m))   returns (index(int))
def decide_time(time):
    if time[:-2] == '':
        h = 0
    else:
        h = int(time[:-2])
    # try:
    m = int(time[-2:])
    # except:
    #     print("ERROR: m is", time[-2:], '!!!')
        
    if m > 30 & h != 23:  # averages the hour up using minutes, unless it rolls over to next day (past 2400)
        h+1
    if h >= 21:
        return 7
    elif h >= 18:
        return 6
    elif h >= 15:
        return 5
    elif h >= 12:
        return 4
    elif h >= 9:
        return 3
    elif h >= 6:
        return 2
    elif h >= 3:
        return 1
    else:
        return 0   # Probably the worst function I've ever wrote, don't know python well enough to make this concise (enumerate instead?)

# %%
airports = pd.read_csv('airports.csv')  # found a database of airports, so with airport IATA code i can get the lat,lon coords for the actual weather around that airport
                                        # not just the whole city. Link to the database: https://davidmegginson.github.io/ourairports-data/airports.csv
def get_latlon(row):                     
    
    IATA = row['origin']          
    latlon = airports[airports['iata_code']==IATA][['latitude_deg','longitude_deg']].values[0]

    return latlon

# %%
def get_weatherDesc(row):
    date, time = row['fl_date'], str(row['crs_dep_time'])
    lat,lon = get_latlon(row)
    time_cursor = decide_time(time)
    # print(date,time,lat,lon,time_cursor)
    url = f"http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=eedc910ff6464b568f6233003221603&q={lat},{lon}&date={date}&num_of_days=1&format=json"
    data = requests.get(url).json()

    weather = data['data']['weather'][0]['hourly'][time_cursor]['weatherDesc'][0]['value']
    return weather

# %%
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0     2019-09-05                 DL       DL_CODESHARE          DL
# 1     2019-12-12                 AA       AA_CODESHARE          AA
# 2     2018-07-26                 AA       AA_CODESHARE          AA
# 3     2019-05-20                 DL                 DL          DL
# 4     2019-11-30                 AS                 AS          AS
# ...          ...                ...                ...         ...
# 1464  2019-05-12                 UA       UA_CODESHARE          UA
# 1465  2019-09-15                 UA       UA_CODESHARE          UA
# 1466  2019-09-02                 AA       AA_CODESHARE          AA
# 1467  2019-06-23                 DL                 DL          DL
# 1468  2018-09-18                 UA       UA_CODESHARE          UA
#
#       mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                   3520                OO   N251SY               3520
# 1                   5274                OH   N551NN               5274
# 2                   4963                PT   N620AE               4963
# 3                   1991                DL   N334DN               1991
# 4                   1233                AS   N624VA               1233
# ...                  ...               ...      ...                ...
# 1464                4220                EV   N16571               4220
# 1465                5688                OO   N857AS               5688
# 1466                5088                OH   N571NN               5088
# 1467                3053                DL   N920DE               3053
# 1468                3765                ZW   N431AW               3765
#
#       origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0                 14869    SLC  ...    575.0            0.0           0.0
# 1                 11057    CLT  ...    168.0            NaN           NaN
# 2                 14100    PHL  ...    198.0            NaN           NaN
# 3                 13487    MSP  ...    907.0            NaN           NaN
# 4                 14908    SNA  ...    978.0            NaN           NaN
# ...                 ...    ...  ...      ...            ...           ...
# 1464              12992    LIT  ...    374.0            NaN           NaN
# 1465              11292    DEN  ...    649.0            NaN           NaN
# 1466              14683    SAT  ...   1095.0            NaN           NaN
# 1467              15096    SYR  ...    794.0            NaN           NaN
# 1468              13930    ORD  ...    122.0            NaN           NaN
#
#      nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0         21.0             0.0                  0.0             NaN
# 1          NaN             NaN                  NaN             NaN
# 2          NaN             NaN                  NaN             NaN
# 3          NaN             NaN                  NaN             NaN
# 4          NaN             NaN                  NaN             NaN
# ...        ...             ...                  ...             ...
# 1464       NaN             NaN                  NaN             NaN
# 1465       NaN             NaN                  NaN             NaN
# 1466       NaN             NaN                  NaN             NaN
# 1467       NaN             NaN                  NaN             NaN
# 1468       NaN             NaN                  NaN             NaN
#
#       total_add_gtime  longest_add_gtime  no_name
# 0                 NaN                NaN      NaN
# 1                 NaN                NaN      NaN
# 2                 NaN                NaN      NaN
# 3                 NaN                NaN      NaN
# 4                 NaN                NaN      NaN
# ...               ...                ...      ...
# 1464              NaN                NaN      NaN
# 1465              NaN                NaN      NaN
# 1466              NaN                NaN      NaN
# 1467              NaN                NaN      NaN
# 1468              NaN                NaN      NaN
#
# [1469 rows x 42 columns]

# %%
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0     2019-09-05                 DL       DL_CODESHARE          DL
# 1     2019-12-12                 AA       AA_CODESHARE          AA
# 2     2018-07-26                 AA       AA_CODESHARE          AA
# 3     2019-05-20                 DL                 DL          DL
# 4     2019-11-30                 AS                 AS          AS
# ...          ...                ...                ...         ...
# 1464  2019-05-12                 UA       UA_CODESHARE          UA
# 1465  2019-09-15                 UA       UA_CODESHARE          UA
# 1466  2019-09-02                 AA       AA_CODESHARE          AA
# 1467  2019-06-23                 DL                 DL          DL
# 1468  2018-09-18                 UA       UA_CODESHARE          UA
#
#       mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                   3520                OO   N251SY               3520
# 1                   5274                OH   N551NN               5274
# 2                   4963                PT   N620AE               4963
# 3                   1991                DL   N334DN               1991
# 4                   1233                AS   N624VA               1233
# ...                  ...               ...      ...                ...
# 1464                4220                EV   N16571               4220
# 1465                5688                OO   N857AS               5688
# 1466                5088                OH   N571NN               5088
# 1467                3053                DL   N920DE               3053
# 1468                3765                ZW   N431AW               3765
#
#       origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0                 14869    SLC  ...    575.0            0.0           0.0
# 1                 11057    CLT  ...    168.0            NaN           NaN
# 2                 14100    PHL  ...    198.0            NaN           NaN
# 3                 13487    MSP  ...    907.0            NaN           NaN
# 4                 14908    SNA  ...    978.0            NaN           NaN
# ...                 ...    ...  ...      ...            ...           ...
# 1464              12992    LIT  ...    374.0            NaN           NaN
# 1465              11292    DEN  ...    649.0            NaN           NaN
# 1466              14683    SAT  ...   1095.0            NaN           NaN
# 1467              15096    SYR  ...    794.0            NaN           NaN
# 1468              13930    ORD  ...    122.0            NaN           NaN
#
#      nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0         21.0             0.0                  0.0             NaN
# 1          NaN             NaN                  NaN             NaN
# 2          NaN             NaN                  NaN             NaN
# 3          NaN             NaN                  NaN             NaN
# 4          NaN             NaN                  NaN             NaN
# ...        ...             ...                  ...             ...
# 1464       NaN             NaN                  NaN             NaN
# 1465       NaN             NaN                  NaN             NaN
# 1466       NaN             NaN                  NaN             NaN
# 1467       NaN             NaN                  NaN             NaN
# 1468       NaN             NaN                  NaN             NaN
#
#       total_add_gtime  longest_add_gtime  no_name
# 0                 NaN                NaN      NaN
# 1                 NaN                NaN      NaN
# 2                 NaN                NaN      NaN
# 3                 NaN                NaN      NaN
# 4                 NaN                NaN      NaN
# ...               ...                ...      ...
# 1464              NaN                NaN      NaN
# 1465              NaN                NaN      NaN
# 1466              NaN                NaN      NaN
# 1467              NaN                NaN      NaN
# 1468              NaN                NaN      NaN
#
# [1469 rows x 42 columns]

# %%
weather_df = df.copy()
weather_df.reset_index()
weather_df
# Out:
#          fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0     2019-09-05                 DL       DL_CODESHARE          DL
# 1     2019-12-12                 AA       AA_CODESHARE          AA
# 2     2018-07-26                 AA       AA_CODESHARE          AA
# 3     2019-05-20                 DL                 DL          DL
# 4     2019-11-30                 AS                 AS          AS
# ...          ...                ...                ...         ...
# 1464  2019-05-12                 UA       UA_CODESHARE          UA
# 1465  2019-09-15                 UA       UA_CODESHARE          UA
# 1466  2019-09-02                 AA       AA_CODESHARE          AA
# 1467  2019-06-23                 DL                 DL          DL
# 1468  2018-09-18                 UA       UA_CODESHARE          UA
#
#       mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                   3520                OO   N251SY               3520
# 1                   5274                OH   N551NN               5274
# 2                   4963                PT   N620AE               4963
# 3                   1991                DL   N334DN               1991
# 4                   1233                AS   N624VA               1233
# ...                  ...               ...      ...                ...
# 1464                4220                EV   N16571               4220
# 1465                5688                OO   N857AS               5688
# 1466                5088                OH   N571NN               5088
# 1467                3053                DL   N920DE               3053
# 1468                3765                ZW   N431AW               3765
#
#       origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0                 14869    SLC  ...    575.0            0.0           0.0
# 1                 11057    CLT  ...    168.0            NaN           NaN
# 2                 14100    PHL  ...    198.0            NaN           NaN
# 3                 13487    MSP  ...    907.0            NaN           NaN
# 4                 14908    SNA  ...    978.0            NaN           NaN
# ...                 ...    ...  ...      ...            ...           ...
# 1464              12992    LIT  ...    374.0            NaN           NaN
# 1465              11292    DEN  ...    649.0            NaN           NaN
# 1466              14683    SAT  ...   1095.0            NaN           NaN
# 1467              15096    SYR  ...    794.0            NaN           NaN
# 1468              13930    ORD  ...    122.0            NaN           NaN
#
#      nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0         21.0             0.0                  0.0             NaN
# 1          NaN             NaN                  NaN             NaN
# 2          NaN             NaN                  NaN             NaN
# 3          NaN             NaN                  NaN             NaN
# 4          NaN             NaN                  NaN             NaN
# ...        ...             ...                  ...             ...
# 1464       NaN             NaN                  NaN             NaN
# 1465       NaN             NaN                  NaN             NaN
# 1466       NaN             NaN                  NaN             NaN
# 1467       NaN             NaN                  NaN             NaN
# 1468       NaN             NaN                  NaN             NaN
#
#       total_add_gtime  longest_add_gtime  no_name
# 0                 NaN                NaN      NaN
# 1                 NaN                NaN      NaN
# 2                 NaN                NaN      NaN
# 3                 NaN                NaN      NaN
# 4                 NaN                NaN      NaN
# ...               ...                ...      ...
# 1464              NaN                NaN      NaN
# 1465              NaN                NaN      NaN
# 1466              NaN                NaN      NaN
# 1467              NaN                NaN      NaN
# 1468              NaN                NaN      NaN
#
# [1469 rows x 42 columns]

# %%
#### WHATEVER YOU DO DON"T TOUCH THIS WE REALLY NEED THOSE API CALLS




for index, row in weather_df.iterrows():
        print('.', end='')
        weather_df.loc[index, 'dep_weather'] = get_weatherDesc(row)
# Out:
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
#### TEST THAT THE JSON IS CORRECTLY PARSED     DON"T TOUCH LOL WE NEED THOSE API CALLS

IATA = 'SJU'

date = '2019-05-15'
lat,lon = latlon = airports[airports['iata_code']==IATA][['latitude_deg','longitude_deg']].values[0]


url = f"http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=eedc910ff6464b568f6233003221603&q={lat},{lon}&date={date}&num_of_days=1&format=json"
data = requests.get(url).json()
data
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 18.44 and Lon -66.00'}],
#   'weather': [{'date': '2019-05-15',
#     'astronomy': [{'sunrise': '05:51 AM',
#       'sunset': '06:50 PM',
#       'moonrise': '03:56 PM',
#       'moonset': '03:30 AM',
#       'moon_phase': 'First Quarter',
#       'moon_illumination': '74'}],
#     'maxtempC': '29',
#     'maxtempF': '85',
#     'mintempC': '26',
#     'mintempF': '78',
#     'avgtempC': '28',
#     'avgtempF': '83',
#     'totalSnow_cm': '0.0',
#     'sunHour': '13.0',
#     'uvIndex': '7',
#     'hourly': [{'time': '0',
#       'tempC': '26',
#       'tempF': '79',
#       'windspeedMiles': '10',
#       'windspeedKmph': '16',
#       'winddirDegree': '127',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '85',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1015',
#       'pressureInches': '30',
#       'cloudcover': '11',
#       'HeatIndexC': '29',
#       'HeatIndexF': '84',
#       'DewPointC': '23',
#       'DewPointF': '74',
#       'WindChillC': '26',
#       'WindChillF': '79',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '29',
#       'FeelsLikeF': '84',
#       'uvIndex': '1'},
#      {'time': '300',
#       'tempC': '26',
#       'tempF': '78',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '131',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '84',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1015',
#       'pressureInches': '30',
#       'cloudcover': '12',
#       'HeatIndexC': '28',
#       'HeatIndexF': '83',
#       'DewPointC': '23',
#       'DewPointF': '73',
#       'WindChillC': '26',
#       'WindChillF': '78',
#       'WindGustMiles': '14',
#       'WindGustKmph': '22',
#       'FeelsLikeC': '28',
#       'FeelsLikeF': '83',
#       'uvIndex': '1'},
#      {'time': '600',
#       'tempC': '27',
#       'tempF': '80',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '133',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '80',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1016',
#       'pressureInches': '30',
#       'cloudcover': '24',
#       'HeatIndexC': '30',
#       'HeatIndexF': '85',
#       'DewPointC': '23',
#       'DewPointF': '73',
#       'WindChillC': '27',
#       'WindChillF': '80',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '30',
#       'FeelsLikeF': '85',
#       'uvIndex': '7'},
#      {'time': '900',
#       'tempC': '29',
#       'tempF': '84',
#       'windspeedMiles': '8',
#       'windspeedKmph': '13',
#       'winddirDegree': '125',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '72',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '33',
#       'HeatIndexF': '91',
#       'DewPointC': '23',
#       'DewPointF': '74',
#       'WindChillC': '29',
#       'WindChillF': '84',
#       'WindGustMiles': '11',
#       'WindGustKmph': '17',
#       'FeelsLikeC': '33',
#       'FeelsLikeF': '91',
#       'uvIndex': '7'},
#      {'time': '1200',
#       'tempC': '29',
#       'tempF': '85',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '109',
#       'winddir16Point': 'ESE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '71',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1016',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '34',
#       'HeatIndexF': '92',
#       'DewPointC': '24',
#       'DewPointF': '74',
#       'WindChillC': '29',
#       'WindChillF': '85',
#       'WindGustMiles': '12',
#       'WindGustKmph': '19',
#       'FeelsLikeC': '34',
#       'FeelsLikeF': '92',
#       'uvIndex': '7'},
#      {'time': '1500',
#       'tempC': '29',
#       'tempF': '84',
#       'windspeedMiles': '11',
#       'windspeedKmph': '18',
#       'winddirDegree': '110',
#       'winddir16Point': 'ESE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.1',
#       'precipInches': '0.0',
#       'humidity': '76',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1015',
#       'pressureInches': '30',
#       'cloudcover': '39',
#       'HeatIndexC': '33',
#       'HeatIndexF': '92',
#       'DewPointC': '24',
#       'DewPointF': '75',
#       'WindChillC': '29',
#       'WindChillF': '84',
#       'WindGustMiles': '15',
#       'WindGustKmph': '25',
#       'FeelsLikeC': '33',
#       'FeelsLikeF': '92',
#       'uvIndex': '7'},
#      {'time': '1800',
#       'tempC': '27',
#       'tempF': '81',
#       'windspeedMiles': '12',
#       'windspeedKmph': '20',
#       'winddirDegree': '120',
#       'winddir16Point': 'ESE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '81',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1016',
#       'pressureInches': '30',
#       'cloudcover': '23',
#       'HeatIndexC': '31',
#       'HeatIndexF': '87',
#       'DewPointC': '24',
#       'DewPointF': '75',
#       'WindChillC': '27',
#       'WindChillF': '81',
#       'WindGustMiles': '17',
#       'WindGustKmph': '27',
#       'FeelsLikeC': '31',
#       'FeelsLikeF': '87',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'tempC': '27',
#       'tempF': '80',
#       'windspeedMiles': '11',
#       'windspeedKmph': '17',
#       'winddirDegree': '131',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '82',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1016',
#       'pressureInches': '30',
#       'cloudcover': '8',
#       'HeatIndexC': '30',
#       'HeatIndexF': '85',
#       'DewPointC': '23',
#       'DewPointF': '74',
#       'WindChillC': '27',
#       'WindChillF': '80',
#       'WindGustMiles': '16',
#       'WindGustKmph': '26',
#       'FeelsLikeC': '30',
#       'FeelsLikeF': '85',
#       'uvIndex': '1'}]}]}}

# %%
weather = data['data']['weather'][0]['hourly'][0]['weatherDesc'][time_cursor]['value']
weather
# Out:
# 'Clear'

# %%
for index, row in df.head(1).iterrows():
    date, time = row['fl_date'], str(row['crs_dep_time'])
    
date,time
# Out:
# ('2019-05-15', '1234')

# %%
time_cursor = decide_time(time)

# %%
time_cursor
# Out:
# 4

# %%
data['data']['weather'][0]
# Out:
# {'date': '2019-05-15',
#  'astronomy': [{'sunrise': '05:51 AM',
#    'sunset': '06:50 PM',
#    'moonrise': '03:56 PM',
#    'moonset': '03:30 AM',
#    'moon_phase': 'First Quarter',
#    'moon_illumination': '74'}],
#  'maxtempC': '29',
#  'maxtempF': '85',
#  'mintempC': '26',
#  'mintempF': '78',
#  'avgtempC': '28',
#  'avgtempF': '83',
#  'totalSnow_cm': '0.0',
#  'sunHour': '13.0',
#  'uvIndex': '7',
#  'hourly': [{'time': '0',
#    'tempC': '26',
#    'tempF': '79',
#    'windspeedMiles': '10',
#    'windspeedKmph': '16',
#    'winddirDegree': '127',
#    'winddir16Point': 'SE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#    'weatherDesc': [{'value': 'Clear'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '85',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1015',
#    'pressureInches': '30',
#    'cloudcover': '11',
#    'HeatIndexC': '29',
#    'HeatIndexF': '84',
#    'DewPointC': '23',
#    'DewPointF': '74',
#    'WindChillC': '26',
#    'WindChillF': '79',
#    'WindGustMiles': '15',
#    'WindGustKmph': '24',
#    'FeelsLikeC': '29',
#    'FeelsLikeF': '84',
#    'uvIndex': '1'},
#   {'time': '300',
#    'tempC': '26',
#    'tempF': '78',
#    'windspeedMiles': '9',
#    'windspeedKmph': '15',
#    'winddirDegree': '131',
#    'winddir16Point': 'SE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#    'weatherDesc': [{'value': 'Clear'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '84',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1015',
#    'pressureInches': '30',
#    'cloudcover': '12',
#    'HeatIndexC': '28',
#    'HeatIndexF': '83',
#    'DewPointC': '23',
#    'DewPointF': '73',
#    'WindChillC': '26',
#    'WindChillF': '78',
#    'WindGustMiles': '14',
#    'WindGustKmph': '22',
#    'FeelsLikeC': '28',
#    'FeelsLikeF': '83',
#    'uvIndex': '1'},
#   {'time': '600',
#    'tempC': '27',
#    'tempF': '80',
#    'windspeedMiles': '9',
#    'windspeedKmph': '14',
#    'winddirDegree': '133',
#    'winddir16Point': 'SE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#    'weatherDesc': [{'value': 'Sunny'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '80',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1016',
#    'pressureInches': '30',
#    'cloudcover': '24',
#    'HeatIndexC': '30',
#    'HeatIndexF': '85',
#    'DewPointC': '23',
#    'DewPointF': '73',
#    'WindChillC': '27',
#    'WindChillF': '80',
#    'WindGustMiles': '13',
#    'WindGustKmph': '21',
#    'FeelsLikeC': '30',
#    'FeelsLikeF': '85',
#    'uvIndex': '7'},
#   {'time': '900',
#    'tempC': '29',
#    'tempF': '84',
#    'windspeedMiles': '8',
#    'windspeedKmph': '13',
#    'winddirDegree': '125',
#    'winddir16Point': 'SE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#    'weatherDesc': [{'value': 'Sunny'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '72',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1017',
#    'pressureInches': '30',
#    'cloudcover': '7',
#    'HeatIndexC': '33',
#    'HeatIndexF': '91',
#    'DewPointC': '23',
#    'DewPointF': '74',
#    'WindChillC': '29',
#    'WindChillF': '84',
#    'WindGustMiles': '11',
#    'WindGustKmph': '17',
#    'FeelsLikeC': '33',
#    'FeelsLikeF': '91',
#    'uvIndex': '7'},
#   {'time': '1200',
#    'tempC': '29',
#    'tempF': '85',
#    'windspeedMiles': '9',
#    'windspeedKmph': '15',
#    'winddirDegree': '109',
#    'winddir16Point': 'ESE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#    'weatherDesc': [{'value': 'Sunny'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '71',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1016',
#    'pressureInches': '30',
#    'cloudcover': '5',
#    'HeatIndexC': '34',
#    'HeatIndexF': '92',
#    'DewPointC': '24',
#    'DewPointF': '74',
#    'WindChillC': '29',
#    'WindChillF': '85',
#    'WindGustMiles': '12',
#    'WindGustKmph': '19',
#    'FeelsLikeC': '34',
#    'FeelsLikeF': '92',
#    'uvIndex': '7'},
#   {'time': '1500',
#    'tempC': '29',
#    'tempF': '84',
#    'windspeedMiles': '11',
#    'windspeedKmph': '18',
#    'winddirDegree': '110',
#    'winddir16Point': 'ESE',
#    'weatherCode': '116',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#    'weatherDesc': [{'value': 'Partly cloudy'}],
#    'precipMM': '0.1',
#    'precipInches': '0.0',
#    'humidity': '76',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1015',
#    'pressureInches': '30',
#    'cloudcover': '39',
#    'HeatIndexC': '33',
#    'HeatIndexF': '92',
#    'DewPointC': '24',
#    'DewPointF': '75',
#    'WindChillC': '29',
#    'WindChillF': '84',
#    'WindGustMiles': '15',
#    'WindGustKmph': '25',
#    'FeelsLikeC': '33',
#    'FeelsLikeF': '92',
#    'uvIndex': '7'},
#   {'time': '1800',
#    'tempC': '27',
#    'tempF': '81',
#    'windspeedMiles': '12',
#    'windspeedKmph': '20',
#    'winddirDegree': '120',
#    'winddir16Point': 'ESE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#    'weatherDesc': [{'value': 'Clear'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '81',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1016',
#    'pressureInches': '30',
#    'cloudcover': '23',
#    'HeatIndexC': '31',
#    'HeatIndexF': '87',
#    'DewPointC': '24',
#    'DewPointF': '75',
#    'WindChillC': '27',
#    'WindChillF': '81',
#    'WindGustMiles': '17',
#    'WindGustKmph': '27',
#    'FeelsLikeC': '31',
#    'FeelsLikeF': '87',
#    'uvIndex': '1'},
#   {'time': '2100',
#    'tempC': '27',
#    'tempF': '80',
#    'windspeedMiles': '11',
#    'windspeedKmph': '17',
#    'winddirDegree': '131',
#    'winddir16Point': 'SE',
#    'weatherCode': '113',
#    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#    'weatherDesc': [{'value': 'Clear'}],
#    'precipMM': '0.0',
#    'precipInches': '0.0',
#    'humidity': '82',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'pressure': '1016',
#    'pressureInches': '30',
#    'cloudcover': '8',
#    'HeatIndexC': '30',
#    'HeatIndexF': '85',
#    'DewPointC': '23',
#    'DewPointF': '74',
#    'WindChillC': '27',
#    'WindChillF': '80',
#    'WindGustMiles': '16',
#    'WindGustKmph': '26',
#    'FeelsLikeC': '30',
#    'FeelsLikeF': '85',
#    'uvIndex': '1'}]}

# %%
weather_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22884/3752410880.py in <module>
# ----> 1 weather_df
#
# NameError: name 'weather_df' is not defined

# %%
###### SAVES ABOVE DATAFRAME FOR OTHER NOTEBOOKS, AND TO SAVE TIME


# weather_df.to_csv('weatherframe.csv',index=False)

# %%
################ LOAD PREMADE DATAFRAMES

weather_df = pd.read_csv('weatherframe.csv')
weather_dfALT = pd.read_csv('weatherframeALT.csv')

# %%
weather_dfALT
# Out:
#          fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0     2019-09-05                 DL       DL_CODESHARE          DL
# 1     2019-12-12                 AA       AA_CODESHARE          AA
# 2     2018-07-26                 AA       AA_CODESHARE          AA
# 3     2019-05-20                 DL                 DL          DL
# 4     2019-11-30                 AS                 AS          AS
# ...          ...                ...                ...         ...
# 1464  2019-05-12                 UA       UA_CODESHARE          UA
# 1465  2019-09-15                 UA       UA_CODESHARE          UA
# 1466  2019-09-02                 AA       AA_CODESHARE          AA
# 1467  2019-06-23                 DL                 DL          DL
# 1468  2018-09-18                 UA       UA_CODESHARE          UA
#
#       mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                   3520                OO   N251SY               3520
# 1                   5274                OH   N551NN               5274
# 2                   4963                PT   N620AE               4963
# 3                   1991                DL   N334DN               1991
# 4                   1233                AS   N624VA               1233
# ...                  ...               ...      ...                ...
# 1464                4220                EV   N16571               4220
# 1465                5688                OO   N857AS               5688
# 1466                5088                OH   N571NN               5088
# 1467                3053                DL   N920DE               3053
# 1468                3765                ZW   N431AW               3765
#
#       origin_airport_id origin  ... carrier_delay  weather_delay nas_delay  \
# 0                 14869    SLC  ...           0.0            0.0      21.0
# 1                 11057    CLT  ...           NaN            NaN       NaN
# 2                 14100    PHL  ...           NaN            NaN       NaN
# 3                 13487    MSP  ...           NaN            NaN       NaN
# 4                 14908    SNA  ...           NaN            NaN       NaN
# ...                 ...    ...  ...           ...            ...       ...
# 1464              12992    LIT  ...           NaN            NaN       NaN
# 1465              11292    DEN  ...           NaN            NaN       NaN
# 1466              14683    SAT  ...           NaN            NaN       NaN
# 1467              15096    SYR  ...           NaN            NaN       NaN
# 1468              13930    ORD  ...           NaN            NaN       NaN
#
#      security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0               0.0                  0.0             NaN              NaN
# 1               NaN                  NaN             NaN              NaN
# 2               NaN                  NaN             NaN              NaN
# 3               NaN                  NaN             NaN              NaN
# 4               NaN                  NaN             NaN              NaN
# ...             ...                  ...             ...              ...
# 1464            NaN                  NaN             NaN              NaN
# 1465            NaN                  NaN             NaN              NaN
# 1466            NaN                  NaN             NaN              NaN
# 1467            NaN                  NaN             NaN              NaN
# 1468            NaN                  NaN             NaN              NaN
#
#       longest_add_gtime  no_name           dep_weather
# 0                   NaN      NaN  Patchy rain possible
# 1                   NaN      NaN                 Sunny
# 2                   NaN      NaN                 Sunny
# 3                   NaN      NaN                 Clear
# 4                   NaN      NaN                Cloudy
# ...                 ...      ...                   ...
# 1464                NaN      NaN  Patchy rain possible
# 1465                NaN      NaN         Partly cloudy
# 1466                NaN      NaN                 Sunny
# 1467                NaN      NaN                 Sunny
# 1468                NaN      NaN  Patchy rain possible
#
# [1469 rows x 43 columns]

# %%
sns.set()
sns.catplot(x="dep_weather", y="arr_delay", data=weather_df, height=7, aspect=24/7)
plt.xticks(rotation=45)
plt.xlabel('Departure Weather')
plt.ylabel('Arrival Delay')
plt.title('Arrival Delays by the Depature Weather Condition')
plt.savefig('WeatherFeatures1.png', bbox_inches='tight')
plt.show()

# %%
sns.set()
sns.catplot(x="dep_weather", y="arr_delay", data=weather_dfALT, height=7, aspect=24/7)
plt.xticks(rotation=45)
plt.xlabel('Departure Weather')
plt.ylabel('Arrival Delay')
plt.title('Arrival Delays by the Depature Weather Condition')
plt.savefig('WeatherFeatures2.png', bbox_inches='tight')
plt.show()

# %%
# sunny, cloudy rain, snow

# %%
sunny = ['Clear']
cloudy = ['Partly cloudy','Overcast','Fog']
rain = ['Light drizzle','Patchy rain possible','Mist','Light rain shower','Moderate or heavy rain shower','Moderate or heavy freezing rain',
           'Torrential rain shower','Moderate rain','Patchy light rain','Heavy rain','Light rain','Moderate rain at times',
           'Patchy light drizzle','Moderate or heavy rain with thunder','Patchy light rain with thunder','Heavy rain at times','Thundery outbreaks possible',
        'Light freezing rain', 'Heavy freezing drizzle']

snow = ['Light snow','Blizzard','Moderate or heavy snow showers','Heavy snow','Moderate snow','Patchy light snow','Moderate or heavy snow with thunder',
       'Light sleet','Blowing snow','Patchy moderate snow','Light snow showers', 'Light sleet showers','Moderate or heavy sleet', 'Patchy sleet possible',
       'Patchy heavy snow', 'Patchy snow possible', 'Ice pellets']

# %%
weather_df.loc[(weather_df.dep_weather.isin(sunny) ),'dep_weather']='Sunny'
weather_df.loc[(weather_df.dep_weather.isin(cloudy) ),'dep_weather']='Cloudy'
weather_df.loc[(weather_df.dep_weather.isin(rain) ),'dep_weather']='Rain'
weather_df.loc[(weather_df.dep_weather.isin(snow) ),'dep_weather']='Snow'

# %%
weather_df['dep_weather'].unique()
# Out:
# array(['Sunny', 'Cloudy', 'Rain', 'Snow'], dtype=object)

# %%
# weather_df.to_csv('weatherframeTrunc.csv',index=False)

# %%
sns.set()
sns.catplot(x="dep_weather", y="arr_delay", data=weather_df, height=5, aspect=8/5)
plt.xticks(rotation=45)
plt.xlabel('Departure Weather')
plt.ylabel('Arrival Delay')
plt.title('Arrival Delays by the Depature Weather Condition')
plt.savefig('WeatherBins.png', bbox_inches='tight')
plt.show()

# %%
# TIME FOR SOME FUN

# mkt_carrier
# origin
# dest
# dest_city_name
# distance
# flights
# carrier_delay
# weather_delay
# air_time
# fl_date

# %%
X = weather_df[['mkt_carrier','distance','origin','dest','crs_dep_time','dep_weather']]
y = weather_df['arr_delay']

# %%
X = X.astype({'mkt_carrier': 'category', 'origin': 'category', 'dest': 'category', 'dep_weather': 'category' })

# %%
X.dtypes
# Out:
# mkt_carrier     category
# distance         float64
# origin          category
# dest            category
# crs_dep_time       int64
# dep_weather     category
# dtype: object

# %%
dummies = pd.get_dummies(X['dep_weather'], drop_first=True)
X = pd.merge(X,dummies, left_index=True, right_index=True)
X
# Out:
#      mkt_carrier  distance origin dest  crs_dep_time dep_weather  Rain  Snow  \
# 0             B6    1666.0    SJU  BDL          1234       Sunny     0     0
# 1             UA     763.0    BTV  ORD           730      Cloudy     0     0
# 2             UA     264.0    CVG  ORD          1125       Sunny     0     0
# 3             AA    1012.0    ORD  TPA          1215       Sunny     0     0
# 4             AA     641.0    DFW  VPS          1220       Sunny     0     0
# ...          ...       ...    ...  ...           ...         ...   ...   ...
# 1476          WN     404.0    SNA  SMF          1740       Sunny     0     0
# 1477          DL     743.0    ATL  DSM          2132       Sunny     0     0
# 1478          AS    2496.0    BOS  SEA          1857        Snow     0     1
# 1479          G4    1144.0    PSM  SFB          1709       Sunny     0     0
# 1480          AA     573.0    ROC  CLT          1200        Snow     0     1
#
#       Sunny
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 1476      1
# 1477      1
# 1478      0
# 1479      1
# 1480      0
#
# [1481 rows x 9 columns]

# %%
X['carrier_cat'] = X['mkt_carrier'].cat.codes
X['origin_cat'] = X['origin'].cat.codes
X['dest_cat'] = X['dest'].cat.codes
X = X.drop(['mkt_carrier','origin','dest','crs_dep_time','dep_weather'], axis=1)
X
# Out:
#       distance  Rain  Snow  Sunny  carrier_cat  origin_cat  dest_cat
# 0       1666.0     0     0      1            2         179        13
# 1        763.0     0     0      0            8          23       124
# 2        264.0     0     0      1            8          44       124
# 3       1012.0     0     0      1            0         136       175
# 4        641.0     0     0      1            0          51       183
# ...        ...   ...   ...    ...          ...         ...       ...
# 1476     404.0     0     0      1           10         183       166
# 1477     743.0     0     0      1            3           8        50
# 1478    2496.0     0     1      0            1          22       156
# 1479    1144.0     0     0      1            5         149       157
# 1480     573.0     0     1      0            0         159        33
#
# [1481 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x = X['distance'].to_numpy().reshape(-1,1)

scaler.fit(x)

x = scaler.transform(x)
x
# Out:
# array([[ 1.53270521],
#        [-0.00919948],
#        [-0.86125977],
#        ...,
#        [ 2.9499598 ],
#        [ 0.6413716 ],
#        [-0.33363125]])

# %%
X['distance'] = x

# %%
X
# Out:
#       distance  Rain  Snow  Sunny  carrier_cat  origin_cat  dest_cat
# 0       1666.0     0     0      1            2         179        13
# 1        763.0     0     0      0            8          23       124
# 2        264.0     0     0      1            8          44       124
# 3       1012.0     0     0      1            0         136       175
# 4        641.0     0     0      1            0          51       183
# ...        ...   ...   ...    ...          ...         ...       ...
# 1476     404.0     0     0      1           10         183       166
# 1477     743.0     0     0      1            3           8        50
# 1478    2496.0     0     1      0            1          22       156
# 1479    1144.0     0     0      1            5         149       157
# 1480     573.0     0     1      0            0         159        33
#
# [1481 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20)

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10, num_parallel_tree=10)

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y, enable_categorical=True)

# %%
xg_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=10, n_jobs=12,
#              num_parallel_tree=10, predictor='auto', random_state=0,
#              reg_alpha=10, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = xg_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.0015519445030326429

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
params = {"objective":"reg:squarederror",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10, 'num_parallel_tree': 10}

# %%
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=5,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True)

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0        50.803926        2.801615       49.961900      11.256005
# 1        50.441279        2.818949       49.908072      11.268166
# 2        50.067065        2.847242       49.878081      11.274499
# 3        49.740167        2.862554       49.835502      11.300030
# 4        49.390332        2.831378       49.802510      11.313263

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
# A parameter grid for XGBoost
params = {
        'n_estimators': [140,150,160],
        'min_child_weight': [4, 5, 6],
        'gamma': [0.8, 1, 1.2, 1.5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [2 ,3, 5],
        'num_parallel_tree': [15,20,25]
        }

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 0.1)

# %%
folds = 3
param_comb = 5
random_search = RandomizedSearchCV(xg_reg, param_distributions=params, n_iter=param_comb, scoring='neg_mean_squared_error', n_jobs=4, verbose=3, random_state=1001 )

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=0.1,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n...
#                                           scale_pos_weight=None, subsample=None,
#                                           tree_method=None,
#                                           validate_parameters=None,
#                                           verbosity=None),
#                    n_iter=5, n_jobs=4,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.8, 1, 1.2, 1.5],
#                                         'max_depth': [2, 3, 5],
#                                         'min_child_weight': [4, 5, 6],
#                                         'n_estimators': [140, 150, 160],
#                                         'num_parallel_tree': [15, 20, 25],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=1001, scoring='neg_mean_squared_error',
#                    verbose=3)

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
results = pd.DataFrame(random_search.cv_results_)
results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
# Out:
#  All results:
# {'mean_fit_time': array([4.42415338, 1.90360975, 2.2079247 , 2.18315797, 1.77442122]), 'std_fit_time': array([0.10641924, 0.05869312, 0.10456049, 0.05743398, 0.18004644]), 'mean_score_time': array([0.01023655, 0.0062777 , 0.0074264 , 0.00622725, 0.00601673]), 'std_score_time': array([0.00040259, 0.00039262, 0.00047959, 0.00040743, 0.00061058]), 'param_subsample': masked_array(data=[0.8, 0.8, 1.0, 0.8, 1.0],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_num_parallel_tree': masked_array(data=[25, 25, 15, 25, 25],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[160, 150, 150, 160, 160],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_min_child_weight': masked_array(data=[6, 5, 6, 5, 6],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[5, 2, 5, 2, 2],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.8, 1, 0.8, 0.8, 0.8],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_colsample_bytree': masked_array(data=[0.8, 0.6, 0.6, 1.0, 1.0],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'subsample': 0.8, 'num_parallel_tree': 25, 'n_estimators': 160, 'min_child_weight': 6, 'max_depth': 5, 'gamma': 0.8, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'num_parallel_tree': 25, 'n_estimators': 150, 'min_child_weight': 5, 'max_depth': 2, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 1.0, 'num_parallel_tree': 15, 'n_estimators': 150, 'min_child_weight': 6, 'max_depth': 5, 'gamma': 0.8, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'num_parallel_tree': 25, 'n_estimators': 160, 'min_child_weight': 5, 'max_depth': 2, 'gamma': 0.8, 'colsample_bytree': 1.0}, {'subsample': 1.0, 'num_parallel_tree': 25, 'n_estimators': 160, 'min_child_weight': 6, 'max_depth': 2, 'gamma': 0.8, 'colsample_bytree': 1.0}], 'split0_test_score': array([-1646.71628614, -1430.49759123, -1562.38148133, -1440.11575455,
#        -1454.67930711]), 'split1_test_score': array([-2000.50776546, -1764.83460599, -1919.24671074, -1821.85635747,
#        -1770.63414906]), 'split2_test_score': array([-3562.06963682, -3328.9988098 , -3560.29111527, -3357.94309588,
#        -3351.24901037]), 'split3_test_score': array([-2649.06417435, -2410.97997589, -2524.19381674, -2436.68486684,
#        -2397.34745431]), 'split4_test_score': array([-3144.8857633 , -2893.95476421, -3098.64988524, -2901.9702424 ,
#        -2951.27504399]), 'mean_test_score': array([-2600.64872522, -2365.85314942, -2532.95260186, -2391.71406343,
#        -2385.03699296]), 'std_test_score': array([706.11960014, 699.24110561, 734.05146614, 696.60023414,
#        706.73885116]), 'rank_test_score': array([5, 1, 4, 3, 2])}
#
#  Best estimator:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.6, enable_categorical=False,
#              gamma=1, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimators=150, n_jobs=12,
#              num_parallel_tree=25, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)
#
#  Best normalized gini score for 3-fold search with 5 parameter combinations:
# -4732.706298842653
#
#  Best hyperparameters:
# {'subsample': 0.8, 'num_parallel_tree': 25, 'n_estimators': 150, 'min_child_weight': 5, 'max_depth': 2, 'gamma': 1, 'colsample_bytree': 0.6}

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree=1.0, learning_rate=0.1,
                          subsample=0.8, min_child_weight=5, max_depth=9, gamma=0.5, alpha=10, n_estimators=100)

# %%
xg_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1.0, enable_categorical=False,
#              gamma=0.5, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=9, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=10, reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = xg_reg.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# -0.14851474328390846

# %%
params = {"objective":"reg:squarederror",'colsample_bytree': 1.0,'learning_rate': 0.1,
          'subsample': 0.8, 'min_child_weight': 5,'max_depth': 9, 'gamma': 0.5,'alpha': 10, 
          'num_parallel_tree': 100}

# %%
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=5,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True)

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0        50.172930        2.749367       49.965568      11.253933
# 1        49.202677        2.719301       49.905621      11.265383
# 2        48.268677        2.682063       49.884656      11.264307
# 3        47.403755        2.658355       49.874522      11.262569

# %%
# A parameter grid for XGBoost
params = {
        'n_estimators': [110,115],
        'min_child_weight': [5],
        'gamma': [1],
        'subsample': [0.8],
        'colsample_bytree': [0.2,0.5,0.7],
        'max_depth': [2, 3],
        'num_parallel_tree': [22,23,None]
        }

# %%
grid = GridSearchCV(xg_reg, param_grid=params, scoring='neg_mean_squared_error', n_jobs=4, verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(estimator=XGBRegressor(alpha=10, base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1.0,
#                                     enable_categorical=False, gamma=0.5,
#                                     gpu_id=-1, importance_type=None,
#                                     interaction_constraints='',
#                                     learning_rate=0.1, max_delta_step=0,
#                                     max_depth=9, min_child_weight=5,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=100...
#                                     random_state=0, reg_alpha=10, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=0.8,
#                                     tree_method='exact', validate_parameters=1,
#                                     verbosity=None),
#              n_jobs=4,
#              param_grid={'colsample_bytree': [0.2, 0.5, 0.7], 'gamma': [1],
#                          'max_depth': [2, 3], 'min_child_weight': [5],
#                          'n_estimators': [110, 115],
#                          'num_parallel_tree': [22, 23, None],
#                          'subsample': [0.8]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(grid.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(grid.best_params_)
# Out:
#  Best normalized gini score for 3-fold search with 5 parameter combinations:
# -4530.2192431428775
#
#  Best hyperparameters:
# {'colsample_bytree': 0.2, 'gamma': 1, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 110, 'num_parallel_tree': 22, 'subsample': 0.8}

# %%
'n_estimators': [110,130,150],
'min_child_weight': [5],
'gamma': [1],
'subsample': [0.8],
'colsample_bytree': [0.2,0.4,0.6],
'max_depth': [2, 3],
'num_parallel_tree': [23,25,26]
# Out:
#   File "C:\Users\richl\AppData\Local\Temp/ipykernel_13672/1970238973.py", line 1
#     'n_estimators': [110,130,150],
#                                  ^
# SyntaxError: invalid syntax

# %%
cv_results.
# Out:
# array([[50.1729088 ,  2.74938418, 49.9655732 , 11.25391733],
#        [49.2026558 ,  2.71932445, 49.9058068 , 11.26547293],
#        [48.2687372 ,  2.68211605, 49.8848762 , 11.26452469],
#        [47.4041738 ,  2.6585365 , 49.8756346 , 11.26276652]])

# %%
from xgboost import plot_importance
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree=0.2, learning_rate=0.1,
                          subsample=0.8, min_child_weight=5, max_depth=2, gamma=1, alpha=10, n_estimators=110, num_parallel_tree=22)

xg_reg.fit(X,y)

plot_importance(xg_reg)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Out:
#     origin dest
# 0      CVG  IAD
# 1      DEN  RDU
# 2      MYR  CLT
# 3      BOS  RSW
# 4      BWI  PWM
# ..     ...  ...
# 995    SDF  DTW
# 996    SAN  SFO
# 997    LIT  DFW
# 998    OKC  LAS
# 999    PHX  DFW
#
# [1000 rows x 2 columns]
